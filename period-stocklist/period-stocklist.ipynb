# %%
import os
import pandas as pd
import numpy as np
from datetime import timedelta
import datetime as dt
import copy

import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter('ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %% [markdown]
# #### Import Data

# %%
#Đọc toàn bộ các file csv được xuất ra từ ami eod
full_stock_dict = {}
folder_path = 'D:\\t2m-project\\ami-data\\full_stock'
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        key = os.path.splitext(filename)[0]
        if len(key) == 3:
            full_stock_dict[key] = pd.read_csv(os.path.join(folder_path, filename)).sort_values('date', ascending=False).reset_index(drop=True)

for item, df in full_stock_dict.items():
    df = df[df['date'] >= 200401]
    df['date'] = pd.to_datetime(df['date'].astype(str), format='%y%m%d', errors='coerce')
    full_stock_dict[item] = df
    full_stock_dict[item]['ma20_volume'] = full_stock_dict[item]['volume'][::-1].rolling(window=20, min_periods=1).mean()[::-1]
    full_stock_dict[item]['value'] = full_stock_dict[item]['volume']*full_stock_dict[item]['close']
    full_stock_dict[item]['ma20_value'] = full_stock_dict[item]['value'][::-1].rolling(window=20, min_periods=1).mean()[::-1]

# %%
q2_2020 = {k: v[(v['date'] >= '2020-04-01') & (v['date'] <= '2020-06-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q2_2020 = [k for k, v in q2_2020.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q3_2020 = {k: v[(v['date'] >= '2020-07-01') & (v['date'] <= '2020-09-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q3_2020 = [k for k, v in q3_2020.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q4_2020 = {k: v[(v['date'] >= '2020-10-01') & (v['date'] <= '2020-12-31')] for k, v in copy.deepcopy(full_stock_dict).items()}
q4_2020 = [k for k, v in q4_2020.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q1_2021 = {k: v[(v['date'] >= '2021-01-01') & (v['date'] <= '2021-03-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q1_2021 = [k for k, v in q1_2021.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q2_2021 = {k: v[(v['date'] >= '2021-04-01') & (v['date'] <= '2021-06-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q2_2021 = [k for k, v in q2_2021.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q3_2021 = {k: v[(v['date'] >= '2021-07-01') & (v['date'] <= '2021-09-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q3_2021 = [k for k, v in q3_2021.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q4_2021 = {k: v[(v['date'] >= '2021-10-01') & (v['date'] <= '2021-12-31')] for k, v in copy.deepcopy(full_stock_dict).items()}
q4_2021 = [k for k, v in q4_2021.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q1_2022 = {k: v[(v['date'] >= '2022-01-01') & (v['date'] <= '2022-03-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q1_2022 = [k for k, v in q1_2022.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q2_2022 = {k: v[(v['date'] >= '2022-04-01') & (v['date'] <= '2022-06-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q2_2022 = [k for k, v in q2_2022.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q3_2022 = {k: v[(v['date'] >= '2022-07-01') & (v['date'] <= '2022-09-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q3_2022 = [k for k, v in q3_2022.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q4_2022 = {k: v[(v['date'] >= '2022-10-01') & (v['date'] <= '2022-12-31')] for k, v in copy.deepcopy(full_stock_dict).items()}
q4_2022 = [k for k, v in q4_2022.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q1_2023 = {k: v[(v['date'] >= '2023-01-01') & (v['date'] <= '2023-03-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q1_2023 = [k for k, v in q1_2023.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q2_2023 = {k: v[(v['date'] >= '2023-04-01') & (v['date'] <= '2023-06-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q2_2023 = [k for k, v in q2_2023.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q3_2023 = {k: v[(v['date'] >= '2023-07-01') & (v['date'] <= '2023-09-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q3_2023 = [k for k, v in q3_2023.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q4_2023 = {k: v[(v['date'] >= '2023-10-01') & (v['date'] <= '2023-12-31')] for k, v in copy.deepcopy(full_stock_dict).items()}
q4_2023 = [k for k, v in q4_2023.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q1_2024 = {k: v[(v['date'] >= '2024-01-01') & (v['date'] <= '2024-03-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q1_2024 = [k for k, v in q1_2024.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

q2_2024 = {k: v[(v['date'] >= '2024-04-01') & (v['date'] <= '2024-06-30')] for k, v in copy.deepcopy(full_stock_dict).items()}
q2_2024 = [k for k, v in q2_2024.items() if (v['volume'].mean() >= 50000) & (v['ma20_volume'].min() >= 20000)&
                                            (v['value'].mean() >= 500000) & (v['ma20_value'].min() >= 200000)]

all_stock = sorted(list(set(q2_2020+q3_2020+q4_2020+q1_2021+q2_2021+q3_2021+q4_2021+q1_2022+q2_2022+q3_2022+q4_2022+q1_2023+q2_2023+q3_2023+q4_2023+q1_2024+q2_2024)))

# %%
data = {
    'all_stock': all_stock,
    'q2_2020': q2_2020,
    'q3_2020': q3_2020,
    'q4_2020': q4_2020,
    'q1_2021': q1_2021,
    'q2_2021': q2_2021,
    'q3_2021': q3_2021,
    'q4_2021': q4_2021,
    'q1_2022': q1_2022,
    'q2_2022': q2_2022,
    'q3_2022': q3_2022,
    'q4_2022': q4_2022,
    'q1_2023': q1_2023,
    'q2_2023': q2_2023,
    'q3_2023': q3_2023,
    'q4_2023': q4_2023,
    'q1_2024': q1_2024,
    'q2_2024': q2_2024,
}

for key, value in data.items():
    print(key, len(value))

# Điền thêm giá trị NaN để đảm bảo các danh sách có cùng chiều dài
for key in data:
    if len(data[key]) < len(all_stock):
        data[key].extend([np.nan] * (len(all_stock) - len(data[key])))

# Tạo DataFrame
period_stock_list = pd.DataFrame(data)
# Out:
# all_stock 634
# q2_2020 216
# q3_2020 271
# q4_2020 304
# q1_2021 394
# q2_2021 418
# q3_2021 424
# q4_2021 528
# q1_2022 512
# q2_2022 445
# q3_2022 395
# q4_2022 355
# q1_2023 311
# q2_2023 354
# q3_2023 407
# q4_2023 343
# q1_2024 366
# q2_2024 392

# %%
with pd.ExcelWriter('test_data.xlsx', engine='openpyxl') as writer:
    period_stock_list.to_excel(writer, sheet_name='sheet1', index=False)
